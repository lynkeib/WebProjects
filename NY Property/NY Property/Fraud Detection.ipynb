# %%
import pandas as pd

# %%
AS = pd.read_csv('Data/AS.csv', index_col = 0)
df = pd.read_csv('Data/NY property data.csv', index_col = 0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
BBLE_AS = AS.sort_values('SUM', ascending = False).head(20)['BBLE'].values

# %%
AS.head()
# Out:
#          BBLE  Euclidean_Distance_HF  Euclidean_Distance_AE        SUM
# 0  1000010101               1.537640               0.685626   2.223267
# 1  1000010201              24.818232              22.858678  47.676909
# 2  1000020001               0.162913               0.070510   0.233423
# 3  1000020023               0.166143               0.061508   0.227652
# 4  1000030001              24.311942              21.891265  46.203207

# %%
df.head()
# Out:
#               BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 1       1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 2       1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 3       1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 4       1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 5       1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#        TAXCLASS  LTFRONT  LTDEPTH   ...    BLDFRONT  BLDDEPTH      AVLAND2  \
# RECORD                              ...
# 1             4      500     1046   ...           0         0    3775500.0
# 2             4       27        0   ...           0         0   11111400.0
# 3             4      709      564   ...         709       564   32321790.0
# 4             4      793      551   ...          85       551   13644000.0
# 5             4      323     1260   ...          89        57  106348680.0
#
#              AVTOT2      EXLAND2       EXTOT2  EXCD2  PERIOD     YEAR  VALTYPE
# RECORD
# 1         8613000.0    3775500.0    8613000.0    NaN   FINAL  2010/11    AC-TR
# 2        80690400.0   11111400.0   80690400.0    NaN   FINAL  2010/11    AC-TR
# 3        40179510.0   32321790.0   40179510.0    NaN   FINAL  2010/11    AC-TR
# 4        15750000.0   13644000.0   15750000.0    NaN   FINAL  2010/11    AC-TR
# 5       107758350.0  106348680.0  107758350.0    NaN   FINAL  2010/11    AC-TR
#
# [5 rows x 31 columns]

# %%
df_new = pd.merge(left = df, right = AS, on = ['BBLE'], how = 'left')

# %%
df_new[df_new['BBLE'].isin(BBLE_AS)].to_csv('Data/Potential Fraud.csv')

# %%
df_new.describe()
# Out:
#                   B         BLOCK           LOT       LTFRONT       LTDEPTH  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   3.215427e+00  4.757239e+03  3.647221e+02  3.663530e+01  8.886159e+01
# std    1.201197e+00  3.676579e+03  8.532152e+02  7.403284e+01  7.639628e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.000000e+00  1.555000e+03  2.300000e+01  1.900000e+01  8.000000e+01
# 50%    3.000000e+00  4.047000e+03  4.900000e+01  2.500000e+01  1.000000e+02
# 75%    4.000000e+00  6.898000e+03  1.430000e+02  4.000000e+01  1.000000e+02
# max    5.000000e+00  1.635000e+04  9.978000e+03  9.999000e+03  9.999000e+03
#
#             STORIES       FULLVAL        AVLAND         AVTOT        EXLAND  \
# count  1.014730e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   5.006918e+00  8.742645e+05  8.506792e+04  2.272382e+05  3.642389e+04
# std    8.365707e+00  1.158243e+07  4.057260e+06  6.877529e+06  3.981576e+06
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  3.040000e+05  9.180000e+03  1.837400e+04  0.000000e+00
# 50%    2.000000e+00  4.470000e+05  1.367800e+04  2.534000e+04  1.620000e+03
# 75%    3.000000e+00  6.190000e+05  1.974000e+04  4.543800e+04  1.620000e+03
# max    1.190000e+02  6.150000e+09  2.668500e+09  4.668309e+09  2.668500e+09
#
#            ...           BLDFRONT      BLDDEPTH       AVLAND2        AVTOT2  \
# count      ...       1.070994e+06  1.070994e+06  2.827260e+05  2.827320e+05
# mean       ...       2.304277e+01  3.992284e+01  2.462357e+05  7.139114e+05
# std        ...       3.557970e+01  4.270715e+01  6.178963e+06  1.165253e+07
# min        ...       0.000000e+00  0.000000e+00  3.000000e+00  3.000000e+00
# 25%        ...       1.500000e+01  2.600000e+01  5.705000e+03  3.391200e+04
# 50%        ...       2.000000e+01  3.900000e+01  2.014500e+04  7.996250e+04
# 75%        ...       2.400000e+01  5.000000e+01  6.264000e+04  2.405510e+05
# max        ...       7.575000e+03  9.393000e+03  2.371005e+09  4.501180e+09
#
#             EXLAND2        EXTOT2         EXCD2  Euclidean_Distance_HF  \
# count  8.744900e+04  1.308280e+05  92948.000000           1.070994e+06
# mean   3.512357e+05  6.567683e+05   1364.041679           2.273795e-01
# std    1.080221e+07  1.607251e+07   1094.705653           2.819274e+00
# min    1.000000e+00  7.000000e+00   1011.000000           1.033915e-02
# 25%    2.090000e+03  2.870000e+03   1017.000000           7.782037e-02
# 50%    3.048000e+03  3.706200e+04   1017.000000           1.175707e-01
# 75%    3.177900e+04  1.068408e+05   1017.000000           2.035619e-01
# max    2.371005e+09  4.501180e+09   7160.000000           1.024721e+03
#
#        Euclidean_Distance_AE           SUM
# count           1.070994e+06  1.070994e+06
# mean            1.074381e-01  3.348177e-01
# std             2.777111e+00  5.593891e+00
# min             4.822726e-03  1.840537e-02
# 25%             2.628844e-02  1.063368e-01
# 50%             3.778002e-02  1.624955e-01
# 75%             5.031924e-02  2.468665e-01
# max             1.024941e+03  2.049661e+03
#
# [8 rows x 23 columns]
