# %%
import pandas as pd
from sklearn.decomposition import PCA
from scipy import stats
import numpy as np
from sklearn.preprocessing import scale
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data/Normalized_Data_45.csv', index_col = 0)

# %%
df.head()
# Out:
#          BBLE  FULLVAL_LOTAREA_By_B  FULLVAL_BLDAREA_By_B  \
# 0  1000010101             -0.060695              0.900334
# 1  1000010201              7.568010              2.510020
# 2  1000020001             -0.019102             -0.035136
# 3  1000020023             -0.051506              0.029037
# 4  1000030001              0.057593              5.924273
#
#    FULLVAL_BLDTOT_By_B  AVLAND_LOTAREA_By_B  AVLAND_BLDAREA_By_B  \
# 0             0.875543            -0.020193             0.234715
# 1             2.430665             2.257913             0.234211
# 2            -0.028216             0.048062             0.002963
# 3             0.078889             0.000277             0.035812
# 4            17.300424             0.200544             3.424277
#
#    AVLAND_BLDTOT_By_B  AVTOT_LOTAREA_By_B  AVTOT_BLDAREA_By_B  \
# 0            0.171356           -0.046539            0.386116
# 1            0.170981           11.044536            1.057236
# 2           -0.001238            0.013932           -0.003906
# 3            0.040688           -0.033180            0.022849
# 4            7.663595            0.125435            2.480728
#
#    AVTOT_BLDTOT_By_B         ...           AVTOT_BLDTOT_By_ZIP3  \
# 0           0.403223         ...                       0.399005
# 1           1.103096         ...                       1.093064
# 2          -0.003508         ...                      -0.004348
# 3           0.044694         ...                       0.043453
# 4           7.795132         ...                       7.729515
#
#    FULLVAL_LOTAREA_By_ALL  FULLVAL_BLDAREA_By_ALL  FULLVAL_BLDTOT_By_ALL  \
# 0               -0.040315                0.815228               0.516371
# 1                5.325068                2.277482               1.472711
# 2               -0.011062               -0.034561              -0.039406
# 3               -0.033852                0.023734               0.026459
# 4                0.042879                5.379022              10.617038
#
#    AVLAND_LOTAREA_By_ALL  AVLAND_BLDAREA_By_ALL  AVLAND_BLDTOT_By_ALL  \
# 0              -0.009311               0.455053              0.266218
# 1               9.277554               0.454095              0.265648
# 2               0.268935               0.014352              0.003780
# 3               0.074137               0.076818              0.067530
# 4               0.890542               6.520353             11.658580
#
#    AVTOT_LOTAREA_By_ALL  AVTOT_BLDAREA_By_ALL  AVTOT_BLDTOT_By_ALL
# 0             -0.026968              0.921792             0.597876
# 1             40.122670              2.490184             1.623048
# 2              0.191938              0.010321             0.002097
# 3              0.021393              0.072847             0.072703
# 4              0.595578              5.816850            11.425531
#
# [5 rows x 46 columns]

# %%
df.describe()
# Out:
#        FULLVAL_LOTAREA_By_B  FULLVAL_BLDAREA_By_B  FULLVAL_BLDTOT_By_B  \
# count          1.070994e+06          1.070994e+06         1.070994e+06
# mean          -2.781150e-17         -8.810514e-18        -2.600694e-18
# std            1.000000e+00          1.000000e+00         1.000000e+00
# min           -6.840049e-02         -6.434431e-02        -5.643475e-02
# 25%           -5.513184e-02         -4.352205e-02        -4.115201e-02
# 50%           -3.676316e-02         -1.091802e-02        -1.181433e-02
# 75%            1.070227e-03          8.208763e-03         6.256513e-03
# max            4.270492e+02          5.248266e+02         4.918919e+02
#
#        AVLAND_LOTAREA_By_B  AVLAND_BLDAREA_By_B  AVLAND_BLDTOT_By_B  \
# count         1.070994e+06         1.070994e+06        1.070994e+06
# mean          5.042162e-19        -1.393229e-18       -1.758122e-18
# std           1.000000e+00         1.000000e+00        1.000000e+00
# min          -2.635654e-02        -1.108156e-02       -1.169700e-02
# 25%          -1.926665e-02        -9.494364e-03       -1.067789e-02
columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1070994 entries, 0 to 1070993
# Data columns (total 46 columns):
# BBLE                           1070994 non-null object
# FULLVAL_LOTAREA_By_B           1070994 non-null float64
# FULLVAL_BLDAREA_By_B           1070994 non-null float64
# FULLVAL_BLDTOT_By_B            1070994 non-null float64
# AVLAND_LOTAREA_By_B            1070994 non-null float64
# AVLAND_BLDAREA_By_B            1070994 non-null float64
# AVLAND_BLDTOT_By_B             1070994 non-null float64
# AVTOT_LOTAREA_By_B             1070994 non-null float64
# AVTOT_BLDAREA_By_B             1070994 non-null float64
# AVTOT_BLDTOT_By_B              1070994 non-null float64
# FULLVAL_LOTAREA_By_TAXCLASS    1070994 non-null float64
# FULLVAL_BLDAREA_By_TAXCLASS    1070994 non-null float64
# FULLVAL_BLDTOT_By_TAXCLASS     1070994 non-null float64
# AVLAND_LOTAREA_By_TAXCLASS     1070994 non-null float64
# AVLAND_BLDAREA_By_TAXCLASS     1070994 non-null float64
# AVLAND_BLDTOT_By_TAXCLASS      1070994 non-null float64
# AVTOT_LOTAREA_By_TAXCLASS      1070994 non-null float64
# AVTOT_BLDAREA_By_TAXCLASS      1070994 non-null float64
# AVTOT_BLDTOT_By_TAXCLASS       1070994 non-null float64
# FULLVAL_LOTAREA_By_ZIP5        1070994 non-null float64
# FULLVAL_BLDAREA_By_ZIP5        1070994 non-null float64
# FULLVAL_BLDTOT_By_ZIP5         1070994 non-null float64
# AVLAND_LOTAREA_By_ZIP5         1070994 non-null float64
# AVLAND_BLDAREA_By_ZIP5         1070994 non-null float64
# AVLAND_BLDTOT_By_ZIP5          1070994 non-null float64
# AVTOT_LOTAREA_By_ZIP5          1070994 non-null float64
# AVTOT_BLDAREA_By_ZIP5          1070994 non-null float64
# AVTOT_BLDTOT_By_ZIP5           1070994 non-null float64
# FULLVAL_LOTAREA_By_ZIP3        1070994 non-null float64
# FULLVAL_BLDAREA_By_ZIP3        1070994 non-null float64
# FULLVAL_BLDTOT_By_ZIP3         1070994 non-null float64
# AVLAND_LOTAREA_By_ZIP3         1070994 non-null float64
# AVLAND_BLDAREA_By_ZIP3         1070994 non-null float64
# AVLAND_BLDTOT_By_ZIP3          1070994 non-null float64
# AVTOT_LOTAREA_By_ZIP3          1070994 non-null float64
# AVTOT_BLDAREA_By_ZIP3          1070994 non-null float64
# AVTOT_BLDTOT_By_ZIP3           1070994 non-null float64
# FULLVAL_LOTAREA_By_ALL         1070994 non-null float64
# FULLVAL_BLDAREA_By_ALL         1070994 non-null float64
# FULLVAL_BLDTOT_By_ALL          1070994 non-null float64
# AVLAND_LOTAREA_By_ALL          1070994 non-null float64
# AVLAND_BLDAREA_By_ALL          1070994 non-null float64
# AVLAND_BLDTOT_By_ALL           1070994 non-null float64
# AVTOT_LOTAREA_By_ALL           1070994 non-null float64
# AVTOT_BLDAREA_By_ALL           1070994 non-null float64
# AVTOT_BLDTOT_By_ALL            1070994 non-null float64
# dtypes: float64(45), object(1)
# memory usage: 384.0+ MB

# %%
df_new = df.copy()

# %%
BBLE = df_new["BBLE"]

# %%
del df_new['BBLE']

# %%
df_new.shape
# Out:
# (1070994, 45)

# %%
mat = df_new.values

# %%
mat
# Out:
# array([[-6.06953291e-02,  9.00333603e-01,  8.75543260e-01, ...,
#         -2.69675417e-02,  9.21792151e-01,  5.97875796e-01],
#        [ 7.56801040e+00,  2.51001984e+00,  2.43066550e+00, ...,
#          4.01226704e+01,  2.49018420e+00,  1.62304777e+00],
#        [-1.91018022e-02, -3.51360381e-02, -2.82164959e-02, ...,
#          1.91937880e-01,  1.03206433e-02,  2.09679687e-03],
#        ...,
#        [-5.14515489e-02,  9.75886907e-03,  4.35846421e-03, ...,
#         -6.40227355e-02, -1.09117285e-02, -9.41979827e-03],
#        [-2.91723081e-02,  3.14605381e-02,  2.21621956e-02, ...,
#         -6.03456171e-02, -9.85705751e-03, -8.38572724e-03],
#        [-7.98588319e-03,  1.35463690e-02,  7.46567370e-03, ...,
#         -5.51898502e-02, -1.06248840e-02, -9.13855645e-03]])

# %%
pca=PCA(n_components=8)

# %%
newData=pca.fit_transform(mat)

# %%
newData.shape
# Out:
# (1070994, 8)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9711626441389866

# %%
df_pca = pd.DataFrame(newData)

# %%
df_pca['BBLE'] = BBLE

# %%
df_pca.shape
# Out:
# (1070994, 9)

# %%
df_pca.head()
# Out:
#            0          1          2         3          4          5          6  \
# 0   2.619631  -1.050166  -0.701037 -0.639667   0.470781   0.853431  -0.963453
# 1  21.555487  48.784965  13.494312 -6.142296   1.930685  18.123750   4.164618
# 2  -0.014236   0.217221  -0.017577  0.127023  -0.014757  -0.103249  -0.047280
# 3   0.171489  -0.192589  -0.120878  0.003208  -0.045045  -0.079808  -0.107460
# 4  39.081468 -10.932879  -5.036673 -6.344450 -12.359707  10.349143 -10.582556
#
#            7        BBLE
# 0  -0.006441  1000010101
# 1   1.037043  1000010201
# 2   0.053289  1000020001
# 3  -0.013175  1000020023
# 4 -11.443255  1000030001

# %%
df_test = df_pca.iloc[:,:-1]

# %%
df_norm_pca = pd.DataFrame(scale(df_test.values))

# %%
df_norm_pca.describe()
# Out:
#                   0             1             2             3             4  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean  -1.592262e-19  3.715277e-18 -1.220734e-18  2.972222e-18 -1.379960e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -5.523464e-02 -3.532489e+02 -3.734528e+02 -1.374067e+02 -2.620035e+02
# 25%   -2.741734e-02 -5.200524e-02 -2.551917e-02  4.165418e-03 -1.324567e-02
# 50%   -1.325376e-02 -2.500217e-02 -1.119934e-02  2.050936e-02  6.587894e-03
# 75%   -3.368170e-03  1.974859e-03  2.596637e-03  3.107457e-02  2.323445e-02
# max    6.399767e+02  6.217572e+02  7.507433e+02  4.888844e+02  4.414824e+02
#
#                   5             6             7
# count  1.070994e+06  1.070994e+06  1.070994e+06
# mean   2.123015e-19  3.927578e-18 -1.167658e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.984803e+02 -3.728210e+02 -2.385642e+02
# 25%   -1.170753e-01 -2.674133e-02 -3.930483e-02
# 50%   -1.595876e-02 -6.769837e-04 -1.457085e-02
# 75%    4.264441e-02  2.533818e-02  1.223135e-02
# max    4.576030e+02  4.220742e+02  3.029731e+02

# %%
df_norm_pca['BBLE'] = BBLE

# %%
df_norm_pca.head()
# Out:
#           0          1         2         3          4          5          6  \
# 0  0.535946  -0.340776 -0.378950 -0.409478   0.385434   0.752969  -0.966496
# 1  4.410000  15.830565  7.294441 -3.931946   1.580675  15.990311   4.177770
# 2 -0.002913   0.070488 -0.009502  0.081313  -0.012082  -0.091095  -0.047430
# 3  0.035085  -0.062495 -0.065342  0.002053  -0.036879  -0.070413  -0.107799
# 4  7.995610  -3.547684 -2.722607 -4.061353 -10.119040   9.130893 -10.615977
#
#            7        BBLE
# 0  -0.007804  1000010101
# 1   1.256324  1000010201
# 2   0.064557  1000020001
# 3  -0.015961  1000020023
# 4 -13.862914  1000030001

# %%
df_norm_pca.to_csv('Data/PCA_Normalized.csv')
